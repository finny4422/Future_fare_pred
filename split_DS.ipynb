# %%
import pandas as pd
import numpy as np

# %%
data_set1 = pd.read_excel('data.xlsx')

# %%
n=len(data_set1)
print(f'The number of rows are {n}')
# Out:
# The number of rows are 10683

# %%
Final_Train_set = data_set1.iloc[:int(0.8*n)]

# %%
Final_Test_set = data_set1.iloc[int(0.8*n):]

# %%
Final_Test_set.reset_index(inplace=True)
Final_Test_set=Final_Test_set.drop(columns=['index'])

# %%
Final_Test_set
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways      27/03/2019     Delhi      Cochin
# 1           Jet Airways       1/05/2019   Kolkata    Banglore
# 2     Multiple carriers       6/03/2019     Delhi      Cochin
# 3     Multiple carriers       6/06/2019     Delhi      Cochin
# 4             Air India      24/06/2019     Delhi      Cochin
# ...                 ...             ...       ...         ...
# 2132           Air Asia       9/04/2019   Kolkata    Banglore
# 2133          Air India      27/04/2019   Kolkata    Banglore
# 2134        Jet Airways      27/04/2019  Banglore       Delhi
# 2135            Vistara      01/03/2019  Banglore   New Delhi
# 2136          Air India       9/05/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → MAA → BOM → COK    05:10         18:50  13h 40m     2 stops
# 1           CCU → DEL → BLR    20:25  14:25 02 May      18h      1 stop
# ...

# %%
Final_Train_set
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 0          IndiGo      24/03/2019  Banglore   New Delhi
# 1       Air India       1/05/2019   Kolkata    Banglore
# 2     Jet Airways       9/06/2019     Delhi      Cochin
# 3          IndiGo      12/05/2019   Kolkata    Banglore
# 4          IndiGo      01/03/2019  Banglore   New Delhi
# ...           ...             ...       ...         ...
# 8541  Jet Airways      18/05/2019   Kolkata    Banglore
# 8542  Jet Airways       1/05/2019   Kolkata    Banglore
# 8543  Jet Airways       9/05/2019   Kolkata    Banglore
# 8544     SpiceJet      24/05/2019   Kolkata    Banglore
# 8545  Jet Airways      15/05/2019   Kolkata    Banglore
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %%
Final_Test_set.to_excel('Final_Test_set.xlsx')
Final_Train_set.to_excel('Final_Train_set.xlsx')
